# %%
from pyspark.sql import SparkSession
import boto3
import tempfile
import os
import io

aws_access_key_id = "AKIA2D6ELNQSYKZ62EIU"
aws_secret_access_key = "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"
spark = SparkSession.builder \
    .appName("DataFrameSQL") \
    .master("local[*]") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .config("spark jars","s3://aws-sam-cli-managed-default-samclisourcebucket-uhkdck5i59ka/hadoop-aws-3.2.2.jar") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.access.key", "AKIA2D6ELNQSYKZ62EIU") \
    .config("spark.hadoop.fs.s3a.secret.key", aws_secret_access_key) \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider","org.apache.hadoop.fs.s3a.TemporaryAWSCredentialsProvider") \
    .getOrCreate()

s3_client = boto3.client("s3")
input_path = s3_client.get_object(Bucket="aws-sam-cli-managed-default-samclisourcebucket-uhkdck5i59ka", Key="persons.csv")
csv_content = input_path['Body'].read().decode('utf-8')

lines_rdd = spark.sparkContext.parallelize(csv_content.split("\n"))
df = spark.read.csv(lines_rdd.map(lambda x: x), header=True)
df.show()

df.createOrReplaceTempView("persons_table")
result = spark.sql("SELECT * FROM persons_table WHERE age < 25")
result.show()

temp_dir = tempfile.mkdtemp()
result.write.csv(temp_dir,header = True,mode ="overwrite")

s3_client.upload_file(os.path.join(temp_dir, os.listdir(temp_dir)[1]), "aws-sam-cli-managed-default-samclisourcebucket-uhkdck5i59ka", "output.csv")
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# DataNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 20
#       8 aws_secret_access_key = "olpzI2ybU1kvzQcmjvXsjvLfHuCSf5UhrIWnjDSN"
#       9 spark = SparkSession.builder \
#      10     .appName("DataFrameSQL") \
#      11     .master("local[*]") \
#    (...)
#      17     .config("spark.hadoop.fs.s3a.aws.credentials.provider","org.apache.hadoop.fs.s3a.TemporaryAWSCredentialsProvider") \
#      18     .getOrCreate()
# ---> 20 s3_client = boto3.client("s3",aws_access_key_id,aws_secret_access_key)
#      21 input_path = s3_client.get_object(Bucket="aws-sam-cli-managed-default-samclisourcebucket-uhkdck5i59ka", Key="persons.csv")
#      22 csv_content = input_path['Body'].read().decode('utf-8')
#
# File ~/Desktop/PySpark/pyspark-env/lib/python3.11/site-packages/boto3/__init__.py:92, in client(*args, **kwargs)
#      86 def client(*args, **kwargs):
#      87     """
# ...
